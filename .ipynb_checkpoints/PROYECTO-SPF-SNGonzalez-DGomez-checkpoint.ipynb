# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
# **Nombres:** Sean Nicolás González Vázquez y Doris Gomez Contreras.
#
#
# **Expediente** : 720083, 713897.
# **Profesor:** Oscar David Jaramillo Zuluaga.

# %% [markdown]
# # <center> <font color='navy'> COVID-19 en Estados Unidos

# %% [markdown]
# ### El link donde se estuvo trabajando el ejercicio en Github fue de: [GitHub Repositorio Proyecto COVID](https://github.com/nicoglez/Proyecto-COVID-19-SPF)

# %% [markdown]
# ## **INDICE DEL PROYECTO**
#
# #### 1. Definicion del Proyecto
#  - Objetivos, Definicion del Problema, Hipotesis, Supuestos y Nodos.
#
# #### 2. Definicion de Base de Datos
#
# #### 3. Filtrado y Limpieza de Base de Datos
#
# #### 4. Simulacion de Montecarlo
#  - Nodo 1: Positivos por COVID
#  - Nodo 2: Muertos por COVID
#  - Nodo 3: Hospitalizados por COVID
#  - Nodo 4: Recuperados de Covid
#
# #### 5. Modelos de Prediccion y Conclusiones
#  - Modelo y Conclusion 1: Positivos por COVID
#  - Modelo y Conclusion 2: Muertos por COVID
#  - Modelo y Conclusion 3: Hospitalizados por COVID
#  - Modelo y Conclusion 4: Recuperados de Covid

# %% [markdown]
# ## <center> <font color='navy'> 1. Definicion del Proyecto <center> <font color='navy'>

# %% [markdown]
#  > **Objetivos del proyecto**.
#
#
# •	**Objetivo General:** Buscar predecir el comportamiento del virus en el futuro tomando en cuenta la cantidad de positivos.
#
# •	**Objetivo Secundario:** Encontrar por medio de la simulación de Montecarlo la probabilidad de morirse en caso de estar infectado.
#
# •	**Objetivo Secundario:** Encontrar por medio de la simulación de Montecarlo la probabilidad de recuperarse en caso de ser positivo.
#
# •	**Objetivo Secundario:** Encontrar la posibilidad de ser hospitalizado en caso de ser infectado.

# %% [markdown]
# > **Definición del Problema**
#
# El COVID-19 es una enfermedad conocida como coronavirus que ha afectado el mundo entero en cuestión de meses, el primer brote se produjo en Wuhan en diciembre de 2019.
#
# En este proyecto buscaremos modelar y simular diferentes variables que van relacionadas con este virus con los datos de Estados Unidos por lo cual nuestro modelo final solo podrá predecir el comportamiento del virus en este país.
#
# La importancia e impacto que este virus ha tomado en la vida diaria, a todos los niveles posibles, a pesar de ser una enfermedad con poco indice de mortalidad (este dato sera comprobado aqui), el corona virus causa una infeccion respiratoria mas fuerte que el resfriado comun, y despues de casi 100 años desde la gripe española, se tuvo una pandemia mundial, asi declarado por la OMS (Organización Mundial de la Salud). Cabe destacar que actualmente el corona virus ha tenido repercusiones sin precedentes en todos los ambitos, tanto economico He aqui la importancia de poder modelar el comportamiento del virus para asi poder predecir sus alcances.
#
# > **Escenarios a simular**
#
# Los nodos o escenarios que elegimos para simular son la cantidad de :
#     - Casos positivos
#     - Personas recuperadas
#     - Personas hospitalizadas
#     - Personas fallecidas
#
# Elegimos estos nodos debido a que nos parece importante predecir el comportamiento del COVID-19, y con sideramos que estos son los datos más representativos.
#
# Los positivos debido a que son la cantidad de personas infectadas, el número de recuperadas para poder analizar qué porcentaje de los casos positivos logran superar el virus, las hospitalizadas que representan las personas que están recibiendo atención médica lo que significa que se encuentran en una situación grave y por último el número de fallecidos que nos indica la mortalidad del virus.

# %%
from IPython.display import Image
Image(filename='img.jpg')

# %% [markdown]
# > **Supuestos**
#
# •	El modelo a realizar únicamente es funcional si y solo sí se predicen o interpretan información o datos para Estados Unidos.
#
# •	Se va a tomar como el día más reciente el último dato que tiene el dataframe que es la información actualizada al día 249 del año 2020.
#
# •	Las variables a modelar son las más significativas para predecir la información más importante del impacto del virus y su comportamiento.
#
# • Los datos que se encuentran en el Data Frame no tienen algun tipo de sesgo o fallo, son correctos
#
# > **Hipotesis**
#
# • Al morir de corona virus no afectan factores extremos como otras enfermedades padecidas por los pacientes.
#
# • Las personas hospitalizadas son hospitalizadas porque estan en un lado extremo del virus, y solo hay dos escenarios despues de n cantidad de tiempo, o se recuperan o mueren. (no quedan en coma u otro efecto secundario de la enfermedad)

# %%
# Importacion de todas las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy import optimize

# %% [markdown]
# ## <center> <font color='navy'> 2. Base de Datos <center> <font color='navy'>

# %% [markdown]
# La base de datos fue obtenida del siguiente link, que contiene bases de datos colaborativas para trabajar, los datos estan actualizados al dia 249 del año 2020. La base de datos es obtenida de un proyecto de seguimiento que esta siendo realizada en conjunto con el NY Times, periodico que hizo publicos los datos. El data set tiene la información condensada de todos las ciudades de Estados Unidos a nivel diario.
#
# Link que lleva al data set en Kaggle: [COVID 19 DATA SET ](https://www.kaggle.com/sudalairajkumar/covid19-in-usa)

# %%
# Lectura de Data Frame
data = pd.read_csv('us_covid19_daily.csv')
data.head()
# Out:
#        date  states  positive  negative  pending  hospitalizedCurrently  \
# 0  20200927      56   7080459  90648092  11136.0                29432.0
# 1  20200926      56   7045170  89982483  11183.0                29554.0
# 2  20200925      56   6997437  89096343  10905.0                29769.0
# 3  20200924      56   6941911  88239824  12008.0                30043.0
# 4  20200923      56   6898139  87416375  10535.0                29905.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                404083.0          6080.0          20049.0
# 1                403325.0          6057.0          20002.0
# 2                402171.0          6133.0          19919.0
# 3                400840.0          6168.0          19555.0
# 4                399252.0          6113.0          19452.0
#
#    onVentilatorCurrently  ...  totalTestResults          lastModified total  \
# 0                 1511.0  ...         101298794  2020-09-27T00:00:00Z     0
# 1                 1509.0  ...         100492536  2020-09-26T00:00:00Z     0
# 2                 1506.0  ...          99488275  2020-09-25T00:00:00Z     0
# 3                 1560.0  ...          98476600  2020-09-24T00:00:00Z     0
# 4                 1544.0  ...          97536247  2020-09-23T00:00:00Z     0
#
#    posNeg  deathIncrease  hospitalizedIncrease negativeIncrease  \
# 0       0            307                   758           665609
# 1       0            866                  1154           886140
# 2       0            844                  1331           856519
# 3       0            921                  1588           823449
# 4       0           1157                  1451           800878
#
#    positiveIncrease  totalTestResultsIncrease  \
# 0             35289                    806258
# 1             47733                   1004261
# 2             55526                   1011675
# 3             43772                    940353
# 4             38567                    923704
#
#                                        hash
# 0  e7c64e674bfc2af02802153452e53628d44c241c
# 1  e98f5076c72de4a27a283d22756b7d0b9a44d41f
# 2  8d311e73fe038522a1a6be4bc3202de206ec0adb
# 3  375a88dd29991abc1946cd7f98f4f20a9e37fb5d
# 4  b4fe7067370631b26f8e988fd2524b5691235a09
#
# [5 rows x 25 columns]

# %% [markdown]
# ## <center> <font color='navy'> 3. Limpieza y filtrado de datos <center> <font color='navy'>

# %%
clean_data = pd.DataFrame()
# Filtrar las variables a analizar
clean_data['positives'] = data.T.loc['positive']
clean_data['recovered'] = data.T.loc['recovered']
clean_data['hospitalized'] = data.T.loc['hospitalizedCurrently']
clean_data['death'] = data.T.loc['death']
# Invertir datos para tener los valores iniciales al principio
clean_data = clean_data.iloc[::-1] 
# Reemplazar index por uno que tenga los vlores de forma descendiente
clean_data['index'] = [i for i in range(len(clean_data['death']))]
clean_data.set_index('index', inplace = True)
# Eliminar hasta primer positivo
clean_data = clean_data.iloc[37:,:]
# llenar valores nulos
clean_data.fillna(0,inplace = True)
# Mostrar la cola del data frame
clean_data
# Out:
#        positives  recovered  hospitalized     death
# index
# 37             0        0.0           0.0       4.0
# 38            18        0.0           0.0       5.0
# 39            50        0.0           0.0       8.0
# 40            94        0.0           0.0      11.0
# 41           142        0.0           0.0      14.0
# ...          ...        ...           ...       ...
# 245      6898139  2672338.0       29905.0  193931.0
# 246      6941911  2710183.0       30043.0  194852.0
# 247      6997437  2727335.0       29769.0  195696.0
# 248      7045170  2750459.0       29554.0  196562.0
# 249      7080459  2766280.0       29432.0  196869.0
#
# [213 rows x 4 columns]

# %% [markdown]
# ## <center> <font color='navy'>4. Simulacion de Montecarlo <center> <font color='navy'>

# %% [markdown]
# ## Simulacion para escenario 1: **Positivos**

# %%
# nombrar variable que contenga datos del df determinados
positivos = clean_data['positives']
positivos.head()
# Out:
# index
# 37      0
# 38     18
# 39     50
# 40     94
# 41    142
# Name: positives, dtype: int64

# %%
# plotear histograma de los datos

J = 10  # Cantidad de particiones del histograma
[freq, x_hist, _] = plt.hist(positivos,bins = J, density = True ); # histograma
plt.show() # mostrar histograma
x_hist = x_hist[1:] # Se obvia el último valor de x para obtener exactamente J muestras de x

# %% [markdown]
# ### Estimacion de la f para el metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad

# %% [markdown]
# Primero en el siguiente codigo se probaron todas las distribuciones posibles en distlist, con:
# ```
# [dist for dist in dir(st) if isinstance(getattr(st, dist), st.rv_continuous)]
# ```
# Que arroja todas las distribuciones continuas que contiene la libreria st, y si dejaron las distribuciones que obtuvieron un menor error para distriuir los datos, para facilitar la visualizacion al lector.

# %%
data = positivos

# Probar diferentes distirbuciones de probabilidad
dist_list = ['bradford', 'beta','expon', 'exponnorm','norm','uniform','foldnorm', 'gennorm', 'ksone', 'kappa4', 'johnsonsb']

y_real, x_real,  _ = plt.hist(data, bins = 15, density = True) #hacer histograma

x_real = x_real[1:] # modificar shape para que rea igual

#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real,y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)*100/y_est).mean(),'%')
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# El error de la distribucion bradford es de 38.33421046165682 %
# El error de la distribucion beta es de 71.93971359008366 %
# El error de la distribucion expon es de 80.58301412134102 %
# El error de la distribucion exponnorm es de 80.82365169556672 %
# El error de la distribucion norm es de 84.99327643452021 %
# El error de la distribucion uniform es de 43.1924882629108 %
# El error de la distribucion foldnorm es de 65.34186037890302 %
# El error de la distribucion gennorm es de 43.19248437306957 %
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:98: RuntimeWarning: floating point number truncated to an integer
#   return -scu._smirnovp(n, x)
# El error de la distribucion ksone es de 43.5098866936486 %
# El error de la distribucion kappa4 es de 37.4248824236662 %
# El error de la distribucion johnsonsb es de 48.50271708941329 %

# %% [markdown]
# Podemos notar que la distribucion que menor error tuvo fue la de la distribucion kappa 4, con un error de 37.42%, procederemos a hacer una prueba de hipotesis para comprobar que la distribucion que tenemos es kappa 4.
#
# Aplicando como hipotesis iniciales que:
#
# * H0: El conjunto de datos distribuye como una funcion de distribucion kappa4
# * H1: El conjunto de datos no distribuye como kappa4

# %% [markdown]
# *Prueba de la Chi Cuadrada*

# %%
param = getattr(st, 'kappa4').fit(x_hist) # obtener los parametros
pi = st.kappa4.pdf(x_hist, *param)
# Cálculo de la esperanza usando la expresión teórica
Ei = x_hist*pi

# Cálculo teórico de la chi cuadrada
x2 = ((freq - Ei)**2 / Ei).sum()
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
m = J-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
# Out:
# Valor de chi cuadrado teorico  =  6.860510859985095
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=6.860510859985095, pvalue=0.6516395876598409)
# Estadístico de chi_cuadrado =  16.918977604620448

# %% [markdown]
# Se acepta H0 debido a que $\chi^2 < \chi^2_{1-\alpha,m}$, por lo tanto, no se puede rechazar que los datos distribuyen como la funcion kappa 4, ademas el p value es grande Y SI ES GRANDE NO RECHAZO

# %% [markdown]
# *Q-Q test*

# %%
# Histograma de las variables creadas
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data,bins = 15, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'kappa4'
params = getattr(st, dist).fit(data)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data, dist=dist, line='q', fit=True, ax=ax[1])

# %% [markdown]
# Podemos observar que los quantiles de los datos reales no se ajustan de manera correcta a los quantiles de la distribucion kappa 4, en medio y al final en su mayoria, por lo cual, al tratar de modelar los datos que se tienen con una distribucion kappa 4, se tendria mucho error, por lo cual,  **Se rechaza H0**.
#
# En conclusion la distribucion kappa4 no es aceptable para modelar este conjunto de datos, se puede obtener una mejor distribucion, asi que se procedera a encontrar una f con Kernel Density Estimation

# %% [markdown]
# ### Estimacion de la f para el metodo de aceptacion rechazo con Kernel Density Estimation

# %%
from statsmodels.nonparametric.kernel_density import KDEMultivariate

# funcion que retorna una funcion de densidad de probabilidad de un conjunto de datos
def kde_statsmodels_mf(x, **kwargs):
    """Multivariate Kernel Density Estimation with Statsmodels"""
    kde = KDEMultivariate(x, 
                          bw='cv_ml',
                          var_type='c', **kwargs)
    return lambda x_grid: kde.pdf(x_grid)

# %%
func_positivos = kde_statsmodels_mf(positivos)
x_g = np.arange(0,8e6,100)
plt.figure()
plt.plot(x_g,func_positivos(x_g));
plt.hist(positivos,bins = 15, density = True);
plt.show()
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)

# %% [markdown]
# ### Metodo de aceptacion rechazo con KDE
#
# Procedemos a aplicar el metodo de aceptacion rechazo con la funcion obtenida por KDE

# %%
# la funcion obtenenida por kde es la siguiente
f = func_positivos
# encontrar el maximo de la funcion y plotearlo
x = np.arange(0,10e6,100)
max_fp = f(optimize.fmin(lambda x:-f(x),0,disp=False))
plt.plot(0,max_fp,'x',lw = 10)
plt.plot(x,func_positivos(x))

# %% [markdown]
# #### Generacion de variables aleatorias montecarlo crudo

# %%
np.random.seed(555555)
def acep_rechazo_positivos(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid positivos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    while i < N:
        R2 = np.random.uniform(0,max_f) 
        R1 = np.random.uniform(0,8e6,1)

        if R2 < f(R1):
            X[i] = R1
            i+=1
    return X


f = func_positivos # funcion
N = 1000 # numero de variables que distribuyen como f a generar

# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
var_aleatorias_montecarlo_p = acep_rechazo_positivos(f,max_fp,N)
len(var_aleatorias_montecarlo_p)
# Out:
# 1000

# %%
x = np.arange(0,7.5e6,100)
print('La media de las variables generadas fue de ', var_aleatorias_montecarlo_p.mean())

plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_montecarlo_p,bins = 15, density = True);
plt.show()
# Out:
# La media de las variables generadas fue de  2843741.9827392357

# %% [markdown]
# #### Generacion de variables aleatorias por medio de reduccion de varianza

# %%
np.random.seed(33333)
def acep_rechazo_strat_pos(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid positivos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    B = 3500
    U2 = np.random.rand(B)
    k = np.arange(0,B)
    v = (U2+k)/B
    j = 0
    while i < N:
        R2 = np.random.uniform(0,max_f)
        R1 = 8e6 * v[j]
        j += 1
        if R2 < f([R1]):
            X[i] = R1
            i+=1
    return X 
    
# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
var_aleatorias_strat_p = acep_rechazo_strat_pos(f,max_fp,N)
len(var_aleatorias_strat_p)
# Out:
# 1000

# %%
print('La media de las variables aleatorias estratificadas es de', var_aleatorias_strat_p.mean() )
x = np.arange(0,7.5e6,100)
plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_strat_p, bins = 15, density = True);
plt.show()
# Out:
# La media de las variables aleatorias estratificadas es de 2744559.61463232

# %% [markdown]
# **Intervalos de confianza y Montecarlo**

# %%
# Media real de los datos
media_real_positivos = clean_data['positives'].mean()
media_real_positivos
# Out:
# 2742034.943661972

# %%
# Intervalos de confianza y media de los datos para metodo de montecarlo curdo
X = var_aleatorias_montecarlo_p
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_positivos = np.mean(X)
#print('Con una confianza de %2.2f la media del numero de positivos por montecarlo crudo  estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media del numero de positivos por montecarlo crudo  estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada por montecarlo crudo del numero de positivos' ,media_positivos)
error_positivos = abs(np.array(media_real_positivos - media_positivos)/media_positivos)
print('El porcentaje de error entre la media real y la media estimada con montecarlo fue de', error_positivos*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de positivos por montecarlo crudo  estará en el intervalo normal,
#  (2729717.3587936223, 2957766.606684849)
# Media calculada por montecarlo crudo del numero de positivos 2843741.9827392357
# El porcentaje de error entre la media real y la media estimada con montecarlo fue de 3.5765213473866018 %

# %%
# Intervalos de confianza y media de los datos para metodo estratificado igualmente espaciado
X = var_aleatorias_strat_p 
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_positivos_strat = np.mean(X)
#print('Con una confianza de %2.2f la media del numero de positivos por estratificado estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media del numero de positivos por estratificado estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada por estratificado del numero de positivos' ,media_positivos_strat)
error_positivos = abs(np.array(clean_data['positives']).mean() - media_positivos_strat)/media_positivos_strat
print('El porcentaje de error entre la media real y la media estimada por estratificado con montecarlo fue de', error_positivos*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de positivos por estratificado estará en el intervalo normal,
#  (2637512.2226333246, 2851607.0066313157)
# Media calculada por estratificado del numero de positivos 2744559.61463232
# El porcentaje de error entre la media real y la media estimada por estratificado con montecarlo fue de 0.0919881993777132 %

# %% [markdown]
# > **Conclusiones Montecarlo Escenario 1**
#
# Los resultados obtenidos modelan de forma aceptable el comportamiento de los positivos de covid, y conseguimos con el metodo de Kernel Density Estimation un mejor resultado del que hubieramos obtenido con las distribuciones conocidas, debido a que ninguna modelo de forma correcta los datos.
#
# El metodo estratificado igualmente espaciado si ayudo a disminuir la varianza de los datos, disminuyendo el intervalo de confianza, y modelando de mejor manera los datos, se disminuyo el error a un 0.09198% lo cual es muy poco

# %% [markdown]
# ## Simulacion para escenario 2: **Muertos**

# %%
# nombrar variable que contenga datos del df determinados
muertos = clean_data['death']
muertos
# Out:
# index
# 37          4.0
# 38          5.0
# 39          8.0
# 40         11.0
# 41         14.0
#          ...
# 245    193931.0
# 246    194852.0
# 247    195696.0
# 248    196562.0
# 249    196869.0
# Name: death, Length: 213, dtype: float64

# %%
# Plotear histograma

J = 15  # Cantidad de particiones del histograma
[freq, x_hist, _]  = plt.hist(muertos,bins = J, density = True); # plotear histograma
plt.show()
x_hist = x_hist[1:] # Se obvia el último valor de x para obtener exactamente J muestras de x

# %% [markdown]
# ### Estimacion de la f para el metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad

# %% [markdown]
# Primero en el siguiente codigo se probaron todas las distribuciones posibles en distlist, con:
# ```
# [dist for dist in dir(st) if isinstance(getattr(st, dist), st.rv_continuous)]
# ```
# Que arroja todas las distribuciones continuas que contiene la libreria st, y si dejaron las distribuciones que obtuvieron un menor error para distriuir los datos, para facilitar la visualizacion al lector.

# %%
data = muertos

# Probar diferentes distirbuciones de probabilidad
dist_list = ['alpha','expon','argus', 'bradford', 'burr', 'genpareto', 'gennorm', 'kappa3','kappa4','ksone','uniform']

y_real, x_real,  _ = plt.hist(data, bins = 15, density = True) #hacer histograma

x_real = x_real[1:] # modificar shape para que rea igual

#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real,y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)/y_est).mean()*100,'%')
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# El error de la distribucion alpha es de 7869.880167943704 %
# El error de la distribucion expon es de 115.22884854061199 %
# El error de la distribucion argus es de 63.79429267683295 %
# El error de la distribucion bradford es de 48.10610759523119 %
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:922: RuntimeWarning: overflow encountered in power
#   - sc.xlog1py(d_+1, x_**(-c_))))
# El error de la distribucion burr es de 57.8206676562624 %
# El error de la distribucion genpareto es de 45.6912756651298 %
# El error de la distribucion gennorm es de 40.187889807810265 %
# El error de la distribucion kappa3 es de 41.06358461761169 %
# El error de la distribucion kappa4 es de 41.446683340538534 %
# El error de la distribucion ksone es de 40.246258027388166 %
# El error de la distribucion uniform es de 40.18779342723005 %
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:98: RuntimeWarning: floating point number truncated to an integer
#   return -scu._smirnovp(n, x)

# %% [markdown]
# Podemos notar que la distribucion que menor error tuvo fue la de la distribucion uniforme,se procedera a hacer una prueba de chi cuadrada para comprobar que la distribucion es uniforme
#
#
# Aplicando como hipotesis iniciales que:
#
# * H0: El conjunto de datos distribuye como una funcion de distribucion uniforme
# * H1: El conjunto de datos distribuye como cualquier otra distribucion de probabilidad

# %% [markdown]
# Prueba de la Chi Cuadrada

# %%
param = getattr(st, 'uniform').fit(x_hist) # obtener los parametros
pi = st.uniform.pdf(x_hist, *param)
# Cálculo de la esperanza usando la expresión teórica
Ei = x_hist*pi

# Cálculo teórico de la chi cuadrada
x2 = ((freq - Ei)**2 / Ei).sum()
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
m = J-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
# Out:
# Valor de chi cuadrado teorico  =  8.571602733166003
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=8.571602733166003, pvalue=0.8574766751747848)
# Estadístico de chi_cuadrado =  23.684791304840576

# %% [markdown]
# No podemos rechazar la $H_0$ por lo tanto los datos distribuyen uniformes, debido a que  $\chi^2<\chi^2_{1-\alpha,m}$.

# %% [markdown]
# Prueba Q-Q

# %%
# Histograma de las variables creadas
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data,bins = 35, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'uniform'
params = getattr(st, dist).fit(data)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data, dist=dist, line='q', fit=True, ax=ax[1])

# %% [markdown]
# **Conclusion**
#
# Podemos observar que los quantiles de los datos reales no se ajustan de manera correcta a los quantiles de la distribucion uniforme, aunque en algunos lados si se acomoda, en general al tratar de modelar los datos que se tienen con una distribucion beta, se tendria mucho error, por lo cual,  **Se rechaza H0**.
#
# En conclusion la distribucion uniforme no es aceptable para modelar este conjunto de datos, asi que se procedera a encontrar una f con Kernel Density Estimation

# %% [markdown]
# ### Estimacion de la f para el metodo de aceptacion rechazo con Kernel Density Estimation

# %%
func_muertos = kde_statsmodels_mf(muertos)
x_m = np.arange(0,200000,100)
plt.figure()
plt.plot(x_m,func_muertos(x_m));
plt.hist(muertos,bins = 35, density = True);
plt.show()
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)

# %% [markdown]
# ### Metodo de aceptacion rechazo con KDE
#
# Procedemos a aplicar el metodo de aceptacion rechazo con la funcion obtenida por KDE

# %%
# la funcion obtenenida por kde es la siguiente
f = func_muertos
# encontrar el maximo de la funcion y plotearlo
x = np.arange(0,200000,100)
max_fm = f(optimize.fmin(lambda x:-f(x),0,disp=False))
plt.plot(0,max_fm,'x',lw = 10)
plt.plot(x,func_muertos(x))

# %% [markdown]
# #### Generacion de variables aleatorias montecarlo crudo

# %%
np.random.seed(666666)
def acep_rechazo_muertos(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid muertos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    
    while i < N:
        R2 = np.random.uniform(0,max_f) 
        R1 = np.random.uniform(0,200000,1)
        if R2 < f(R1):
            X[i] = R1
            i+=1
    return X


f = func_muertos # funcion
N = 1000 # numero de variables que distribuyen como f a generar

# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
var_aleatorias_montecarlo_m = acep_rechazo_muertos(f,max_fm,N)
len(var_aleatorias_montecarlo_m)
# Out:
# 1000

# %%
print('La media por montecarlo crudo es de', var_aleatorias_montecarlo_m.mean())
x = np.arange(0,200000,100)
plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_montecarlo_m,bins = 25,density = True);
plt.show()
# Out:
# La media por montecarlo crudo es de 103383.27749597252

# %% [markdown]
# #### Generacion de variables aleatorias por medio de reduccion de varianza

# %%
np.random.seed(66666)
def acep_rechazo_strat2_d(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid positivos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    B = 3700
    U2 = np.random.rand(B)
    k = np.arange(0,B)
    v = (U2+k)/B
    j = 0
    while i < N:
        R2 = np.random.uniform(0,max_f)
        R1 = 200000 * v[j]
        j += 1
        if R2 < f([R1]):
            X[i] = R1
            i+=1
    return X 
    
# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
N = 1000
var_aleatorias_strat2_d = acep_rechazo_strat2_d(f,max_fm,N)
len(var_aleatorias_strat2_d)
# Out:
# 1000

# %%
print('La media de las variables generadas por estratificado con diferentes intervalos es de',var_aleatorias_strat2_d.mean() )
x = np.arange(0,200000,100)
plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_strat2_d,bins = 30,density = True);
plt.show()
# Out:
# La media de las variables generadas por estratificado con diferentes intervalos es de 102080.61545403095

# %% [markdown]
# **Montecarlo y media de datos**

# %%
# Calcular la media real de los muertos
media_real_muertos = np.array(clean_data['death']).mean()
media_real_muertos
# Out:
# 98673.64319248826

# %%
# Intervalos de confianza y media de los datos
X = var_aleatorias_montecarlo_m
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_muertos= np.mean(X)
#print('Con una confianza de %2.2f la media del numero de muertos por montecarlo crudo estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media del numero de muertos por montecarlo crudo estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada del numero de muertos' ,media_muertos)
error_muertos = abs(media_real_muertos - media_muertos)/media_muertos
print('El porcentaje de error entre la media real y la media estimada con montecarlo crudo fue de', error_muertos*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de muertos por montecarlo crudo estará en el intervalo normal,
#  (100246.66351324064, 106519.8914787044)
# Media calculada del numero de muertos 103383.27749597252
# El porcentaje de error entre la media real y la media estimada con montecarlo crudo fue de 4.555508799445568 %

# %%
# Intervalos de confianza y media de los datos
X = var_aleatorias_strat2_d 
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_muertos_strat = np.mean(X)
#print('Con una confianza de %2.2f la media del numero de muertos estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media del numero de muertos estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada del numero de muertos' ,media_muertos_strat)
error_muertos = abs(media_real_muertos - media_muertos_strat)/media_muertos_strat
print('El porcentaje de error entre la media real y la media estimada con montecarlo fue de', error_muertos*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de muertos estará en el intervalo normal,
#  (99001.84663003572, 105159.38427802616)
# Media calculada del numero de muertos 102080.61545403095
# El porcentaje de error entre la media real y la media estimada con montecarlo fue de 3.3375310742291893 %

# %% [markdown]
# > **Conclusiones Escenario 2**
#
# Los resultados obtenidos modelan de forma aceptable el comportamiento de los muertos de covid, y conseguimos con el metodo de Kernel Density Estimation un mejor resultado del que hubieramos obtenido con las distribuciones conocidas, debido a que ninguna modelo de forma correcta los datos.
#
# El metodo estratificado igualmente espaciado si ayudo a disminuir la varianza de los datos, disminuyendo el intervalo de confianza, y modelando de mejor manera los datos

# %% [markdown]
# ## Simulacion para escenario 3: **Hospitalizados**

# %%
# nombrar variable que contenga datos del df determinados
hospitalizados = clean_data['hospitalized']
hospitalizados.tail()
# Out:
# index
# 245    29905.0
# 246    30043.0
# 247    29769.0
# 248    29554.0
# 249    29432.0
# Name: hospitalized, dtype: float64

# %%
# Plotear histograma

J = 15 # Cantidad de particiones del histograma
[freq3, x_hist3, _]  = plt.hist(hospitalizados,bins = J, density = True); # plotear histograma
plt.show()
x_hist3 = x_hist3[1:] # Se obvia el último valor de x para obtener exactamente J muestras de x

# %% [markdown]
# ### Estimacion de la f para el metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad

# %% [markdown]
# Primero en el siguiente codigo se probaron todas las distribuciones posibles en distlist, con:
# ```
# [dist for dist in dir(st) if isinstance(getattr(st, dist), st.rv_continuous)]
# ```
# Que arroja todas las distribuciones continuas que contiene la libreria st, y si dejaron las distribuciones que obtuvieron un menor error para distriuir los datos, para facilitar la visualizacion al lector.

# %%
data = hospitalizados

# Probar diferentes distirbuciones de probabilidad
dist_list = ['genhalflogistic', 'ksone', 'kappa4','gausshyper'] # distribuciones que tuvieron menos de 100% de error

y_real, x_real,  _ = plt.hist(data, bins = 15, density = True) #hacer histograma

x_real = x_real[1:] # modificar shape para que rea igual

#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real,y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)/y_est).mean()*100,'%')
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:3093: RuntimeWarning: divide by zero encountered in power
#   tmp0 = tmp**(limit-1)
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:3094: RuntimeWarning: invalid value encountered in multiply
#   tmp2 = tmp0*tmp
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:98: RuntimeWarning: floating point number truncated to an integer
#   return -scu._smirnovp(n, x)
# El error de la distribucion genhalflogistic es de 84.46664960942083 %
# El error de la distribucion ksone es de 74.99495370627159 %
# El error de la distribucion kappa4 es de 71.45472895667052 %
# El error de la distribucion gausshyper es de 83.8461532477759 %
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:3487: RuntimeWarning: divide by zero encountered in power
#   return 1.0/Cinv * x**(a-1.0) * (1.0-x)**(b-1.0) / (1.0+z*x)**c

# %% [markdown]
# La distribucion que menor error tuvo fue la de la distribucion kappa4, con un error de 71.45%, se procedera a hacer una prueba de chi cuadrada.
#
# Aplicando como hipotesis iniciales que:
#
# * H0: El conjunto de datos distribuye como una funcion de distribucion kappa4
# * H1: El conjunto de datos no distribuye como kp4

# %% [markdown]
# *Prueba de la Chi Cuadrada*

# %%
param = getattr(st, 'kappa4').fit(x_hist3) # obtener los parametros
pi = st.kappa4.pdf(x_hist3, *param)
# Cálculo de la esperanza usando la expresión teórica
Ei = x_hist3*pi

# Cálculo teórico de la chi cuadrada
x2 = ((freq3 - Ei)**2 / Ei).sum()
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq3, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
m = J-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
# Out:
# Valor de chi cuadrado teorico  =  8.529203226539213
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=8.529203226539213, pvalue=0.85997725127324)
# Estadístico de chi_cuadrado =  23.684791304840576

# %% [markdown]
# Podemos observar que a pesar de que nos dio mucho error a la hora de probarle la distribucion a los datos, en este caso se paso la prueba se chi cuadrada debido a que el p value es grande, ademas de que el chi cuadrado teorico dio mas bajo que el estadisco. Asi que se procedera a hacer una prueba de Q-Q para confirmar que no estemos teniendo un falso positivo

# %% [markdown]
# Prueba de Q-Q

# %%
data = hospitalizados

# Histograma de las variables creadas
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data,bins = 20, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'kappa4'
params = getattr(st, dist).fit(data)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data, dist=dist, line='q', fit=True, ax=ax[1])

# %% [markdown]
# **Conclusion**
#
# Si bien, se paso la prueba de chi cuadrada, en este caso podemos observar que en la prueba de Q-Q, en el centro y en ambas colas la distribucion no se acerca a modelar el comportamiento de las variables aleatorias, ademas de que claramente, se ve un sesgo de la distribucion al histograma de los datos.
#
# En conclusion, ninguna funcion de distribucion de probabilidad conocida pudo acercarse correctamente a modelar los datos, por lo cual se trataran de modelar por KDE

# %% [markdown]
# ### Estimacion de la f para el metodo de aceptacion rechazo con Kernel Density Estimation

# %%
func_hospitalizados = kde_statsmodels_mf(hospitalizados)
x_h = np.arange(0,60000,100)
plt.figure()
plt.plot(x_h,func_hospitalizados(x_h));
plt.hist(hospitalizados,bins = 15, density = True);
plt.show()
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)

# %% [markdown]
# ### Metodo de aceptacion rechazo con KDE
#
# Procedemos a aplicar el metodo de aceptacion rechazo con la funcion obtenida por KDE

# %%
# la funcion obtenenida por kde es la siguiente
f = func_hospitalizados
# encontrar el maximo de la funcion y plotearlo
x = np.arange(0,60000,100)
max_fh = f(optimize.fmin(lambda x:-f(x),30000,disp=False))
plt.plot(30000,max_fh,'x',lw = 10)
plt.plot(x,func_hospitalizados(x))

# %% [markdown]
# #### Generacion de variables aleatorias montecarlo crudo

# %%
np.random.seed(8888)
def acep_rechazo_hospitalizados(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid muertos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    while i < N:
        R2 = np.random.uniform(0,max_f) 
        R1 = np.random.uniform(0,60000,1)
        if R2 < f(R1):
            X[i] = R1
            i+=1
    return X


f = func_hospitalizados # funcion
N = 1000 # numero de variables que distribuyen como f a generar

# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
var_aleatorias_montecarlo_h = acep_rechazo_hospitalizados(f,max_fh,N)
len(var_aleatorias_montecarlo_h)
# Out:
# 1000

# %%
print('La media por montecarlo crudo es de', var_aleatorias_montecarlo_h.mean())
x = np.arange(0,60000,100)
plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_montecarlo_h,bins = 25,density = True);
plt.show()
# Out:
# La media por montecarlo crudo es de 37279.400164478604

# %% [markdown]
# #### Generacion de variables aleatorias por medio de reduccion de varianza

# %%
np.random.seed(66666)
def acep_rechazo_strat2_h(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid positivos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    B = 3100
    U2 = np.random.rand(B)
    k = np.arange(0,B)
    v = (U2+k)/B
    j = 0
    while i < N:
        R2 = np.random.uniform(0,max_f)
        R1 = 60000 * v[j]
        j += 1
        if R2 < f([R1]):
            X[i] = R1
            i+=1
    return X 
    
# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
N = 1000
var_aleatorias_strat2_h = acep_rechazo_strat2_h(f,max_fh,N)
len(var_aleatorias_strat2_h)
# Out:
# 1000

# %%
print('La media de las variables generadas por estratificado con diferentes intervalos es de',var_aleatorias_strat2_h.mean() )
x = np.arange(0,60000,100)
plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_strat2_h,bins = 30,density = True);
plt.show()
# Out:
# La media de las variables generadas por estratificado con diferentes intervalos es de 36317.45470055753

# %% [markdown]
# **Montecarlo y media de datos**

# %%
# Calcular la media real de los hospitalizados
media_real_h= np.array(clean_data['hospitalized']).mean()
media_real_h
# Out:
# 36337.52112676056

# %%
# Intervalos de confianza y media de los datos
X = var_aleatorias_montecarlo_h
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_hospitalizados= np.mean(X)
#print('Con una confianza de %2.2f la media del numero de muertos por montecarlo crudo estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media del numero de muertos por montecarlo crudo estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada del numero de muertos' ,media_hospitalizados)
error_hospitalizados = abs(media_real_h - media_hospitalizados)/media_hospitalizados
print('El porcentaje de error entre la media real y la media estimada con montecarlo crudo fue de', error_hospitalizados*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de muertos por montecarlo crudo estará en el intervalo normal,
#  (36440.729560010404, 38118.0707689468)
# Media calculada del numero de muertos 37279.400164478604
# El porcentaje de error entre la media real y la media estimada con montecarlo crudo fue de 2.526540216748186 %

# %%
# Intervalos de confianza y media de los datos
X = var_aleatorias_strat2_h
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_hospitalizados_strat = np.mean(X)
#print('Con una confianza de %2.2f la media del numero de muertos estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media del numero de muertos estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada del numero de muertos' ,media_hospitalizados_strat)
error_hospitalizados = abs(media_real_h - media_hospitalizados_strat)/media_hospitalizados_strat
print('El porcentaje de error entre la media real y la media estimada con montecarlo fue de', error_hospitalizados*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de muertos estará en el intervalo normal,
#  (35549.164647994476, 37085.74475312058)
# Media calculada del numero de muertos 36317.45470055753
# El porcentaje de error entre la media real y la media estimada con montecarlo fue de 0.0552528429331947 %

# %% [markdown]
# **Conclusion escenario 3**
#
# Podemos observar que el metodo de KDE ayudo en gran medida a poder simular los datos de las personas hospitalizadas de CO-VID a lo largo del tiempo, el error que se tuvo respecto a las variables generadas por el metodo de montecarlo con metodos de reduccion de varianza fue demasiado bueno, con un error de apenas 0.055% con respecto a la media real de los datos, considerando que se esta trabajando con datos reales y escalas grandes que pueden dar pie a un error mayor, el resultado al generar las variables aleatorias fue realmente bueno y se acerco muchisimo el KDE a la distribucion real de los datos.

# %% [markdown]
# ## Simulacion para escenario 4: **Recuperados**

# %%
# nombrar variable que contenga datos del df determinados
recuperados = pd.DataFrame(clean_data['recovered'])
recuperados = np.array(recuperados.iloc[25:,:])

# %%
# Plotear histograma

J = 15# Cantidad de particiones del histograma
[freq4, x_hist4, _]  = plt.hist(recuperados, J, density = True); # plotear histograma
plt.show()
x_hist4 = x_hist4[1:] # Se obvia el último valor de x para obtener exactamente J muestras de x

# %% [markdown]
# ### Estimacion de la f para el metodo de la transformada inversa por medio de la comprobacion de distribucion de probabilidad
# Primero en el siguiente codigo se probaron todas las distribuciones posibles en distlist, con:
# ```
# [dist for dist in dir(st) if isinstance(getattr(st, dist), st.rv_continuous)]
# ```
# Que arroja todas las distribuciones continuas que contiene la libreria st, y si dejaron las distribuciones que obtuvieron un menor error para distriuir los datos, para facilitar la visualizacion al lector.

# %%
data = recuperados

# Probar diferentes distirbuciones de probabilidad
dist_list = ['bradford','expon','genhalflogistic','gumbel_r','genexpon','halflogistic','kappa4','ksone']# distribuciones que tuvieron menos de 100% de error

y_real, x_real,  _ = plt.hist(data, bins = 15, density = True) #hacer histograma

x_real = x_real[1:] # modificar shape para que rea igual

#e = []
def distribucion(dist_list):
    
    def imprimir(dist):
        param = getattr(st, dist).fit(data)
        y_est = getattr(st, dist).pdf(x_real, *param)
        plt.plot(x_real,y_est, label = dist);
        print('El error de la distribucion', dist,'es de', (abs(y_real-y_est)/y_est).mean()*100,'%')
        
    [imprimir(dist) for dist in dist_list]


distribucion(dist_list)
plt.legend()
plt.show()
# Out:
# El error de la distribucion bradford es de 25.63571591478404 %
# El error de la distribucion expon es de 70.35464916351582 %
# El error de la distribucion genhalflogistic es de 65.42344667025222 %
# El error de la distribucion gumbel_r es de 85.29789915758673 %
# El error de la distribucion genexpon es de 80.73443348027249 %
# El error de la distribucion halflogistic es de 67.9089132896139 %
# El error de la distribucion kappa4 es de 36.3271353492368 %
# El error de la distribucion ksone es de 47.764744612840424 %
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:98: RuntimeWarning: floating point number truncated to an integer
#   return -scu._smirnovp(n, x)

# %% [markdown]
# La distribucion que menor error tuvo fue la de la distribucion beta, con un error de 35%, se procedera a hacer una prueba de chi cuadrada.
#
# Aplicando como hipotesis iniciales que:
#
# * H0: El conjunto de datos distribuye como una funcion de distribucion beta
# * H1: El conjunto de datos no distribuye como beta

# %% [markdown]
# *Prueba de la Chi Cuadrada*

# %%
param = getattr(st, 'bradford').fit(x_hist4) # obtener los parametros
pi = st.bradford.pdf(x_hist4, *param)
# Cálculo de la esperanza usando la expresión teórica
Ei = x_hist4*pi

# Cálculo teórico de la chi cuadrada
x2 = ((freq4 - Ei)**2 / Ei).sum()
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq4, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
m = J-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
# Out:
# Valor de chi cuadrado teorico  =  7.725171491334054
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=7.725171491334054, pvalue=0.9031468748274993)
# Estadístico de chi_cuadrado =  23.684791304840576

# %% [markdown]
# Podemos observar que a parece ser que la distribucion bradford si modela de forma parecida los datos, en este caso se paso la prueba se chi cuadrada debido a que el p value es grande, ademas de que el chi cuadrado teorico dio mas bajo que el estadistico, se confirmara con una prueba de Q-Q

# %% [markdown]
# Prueba de Q-Q

# %%
data = recuperados

# Histograma de las variables creadas
fig, ax = plt.subplots(2,1, figsize=(8,9))

y, x, _ = ax[0].hist(data,bins = 20, density=True)
x = x[1:]
plt.grid()
ax[0].grid()
#datos
dist = 'bradford'
params = getattr(st, dist).fit(data)
# Graficar PDF de la distribución que queremos probar
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')

import statsmodels.api as sm 
grap1 = sm.qqplot(data, dist=dist, line='q', fit=True, ax=ax[1])

# %% [markdown]
# Podemos observar de la prueba de Q-Q que la distribucion bradford no modela los datos de buena manera en el centro, por lo cual se procedera a una KDE para encontrar una distribucion especifica para este conjunto de datos

# %% [markdown]
# ### Estimacion de la f para el metodo de aceptacion rechazo con Kernel Density Estimation

# %%
func_recuperados = kde_statsmodels_mf(recuperados)
x_r = np.arange(0,3e6,100)
plt.figure()
plt.plot(x_r,func_recuperados(x_r));
plt.hist(recuperados,bins = 10, density = True);
plt.show()
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\statsmodels\nonparametric\kernel_density.py:158: RuntimeWarning: invalid value encountered in log
#   L += func(f_i)

# %% [markdown]
# ### Metodo de aceptacion rechazo con KDE
#
# Procedemos a aplicar el metodo de aceptacion rechazo con la funcion obtenida por KDE

# %%
# la funcion obtenenida por kde es la siguiente
f = func_recuperados
# encontrar el maximo de la funcion y plotearlo
x = np.arange(0,3e6,100)
max_fr = f(optimize.fmin(lambda x:-f(x),0,disp=False))
plt.plot(0.05e6,max_fr,'x',lw = 10)
plt.plot(x,func_recuperados(x))

# %% [markdown]
# #### Generacion de variables aleatorias montecarlo crudo

# %%
np.random.seed(66666)
def acep_rechazo_recuperados(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid muertos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    while i < N:
        R2 = np.random.uniform(0,max_f) 
        R1 = np.random.uniform(0,3e6,1)
        if R2 < f(R1):
            X[i] = R1
            i+=1
    return X


f = func_recuperados # funcion
N = 1000 # numero de variables que distribuyen como f a generar

# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
var_aleatorias_montecarlo_r = acep_rechazo_recuperados(f,max_fr,N)
len(var_aleatorias_montecarlo_r)
# Out:
# 1000

# %%
print('La media por montecarlo crudo es de', var_aleatorias_montecarlo_r.mean())
x = np.arange(0,3e6,100)
plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_montecarlo_r,bins = 15,density = True);
plt.show()
# Out:
# La media por montecarlo crudo es de 1061901.4710207258

# %% [markdown]
# #### Generacion de variables aleatorias por medio de reduccion de varianza

# %%
np.random.seed(66666)
def acep_rechazo_strat2_r(f:'función objetivo a generar',
                 max_f:'maximo de la funcion',
                 N: 'numero de variables aleatorias distribuidas a generar'):
    '''Funcion para hacer el metodo de aceptacion de rechazo especificamente para los datos de covid positivos,
    regresa las variables aleatorias aceptadas'''
    X = np.zeros(N)
    i = 0 
    B = 3300
    U2 = np.random.rand(B)
    k = np.arange(0,B)
    v = (U2+k)/B
    j = 0
    while i < N:
        R2 = np.random.uniform(0,max_f)
        R1 = 3e6 * v[j]
        j += 1
        if R2 < f([R1]):
            X[i] = R1
            i+=1
    return X 
    
# Usar func anteriormente definida como acep_rechazo_aleatorias que genera variables aleatorias
N = 1000
var_aleatorias_strat2_r = acep_rechazo_strat2_r(f,max_fr,N)
len(var_aleatorias_strat2_r)
# Out:
# 1000

# %%
print('La media de las variables generadas por estratificado',var_aleatorias_strat2_r.mean() )
x = np.arange(0,3e6,100)
plt.figure()
plt.plot(x,f(x))
plt.hist(var_aleatorias_strat2_r,bins = 30,density = True);
plt.show()
# Out:
# La media de las variables generadas por estratificado 1006938.0961837864

# %% [markdown]
# **Montecarlo y media de datos**

# %%
# Calcular la media real de los hospitalizados
media_real_r= recuperados.mean()
media_real_r
# Out:
# 1006187.9361702128

# %%
# Intervalos de confianza y media de los datos
X = var_aleatorias_montecarlo_r
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_recuperados= np.mean(X)
print('Con una confianza de %2.2f la media del numero de recuperados por montecarlo crudo estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada del numero de muertos' ,media_recuperados)
error_recuperados= abs(media_real_r - media_recuperados)/media_recuperados
print('El porcentaje de error entre la media real y la media estimada con montecarlo crudo fue de', error_recuperados*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de recuperados por montecarlo crudo estará en el intervalo normal,
#  (1018406.802982496, 1105396.1390589555)
# Media calculada del numero de muertos 1061901.4710207258
# El porcentaje de error entre la media real y la media estimada con montecarlo crudo fue de 5.246582321517999 %

# %%
# Intervalos de confianza y media de los datos
X = var_aleatorias_strat2_r
confianza = 0.90
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.norm.interval(confianza, loc=np.mean(X), scale=st.sem(X))
media_recuperados_strat = np.mean(X)
print('Con una confianza de %2.2f la media del numero de recuperados estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada del numero de muertos' ,media_recuperados_strat)
error_recuperados = abs(media_real_r - media_recuperados_strat)/media_recuperados_strat
print('El porcentaje de error entre la media real y la media estimada con montecarlo fue de', error_recuperados*100,'%')
# Out:
# Con una confianza de 0.90 la media del numero de recuperados estará en el intervalo normal,
#  (965293.4809619789, 1048582.711405594)
# Media calculada del numero de muertos 1006938.0961837864
# El porcentaje de error entre la media real y la media estimada con montecarlo fue de 0.07449911930203446 %

# %% [markdown]
# **Conclusion escenario 4**
#
# A comparacion de los resultados inicialmente obtenidos en este proyecto, notamos una gran mejora en los modelos a la hora de quitar los ceros que tenian los datos y al usar el metodo de KDE, ya que, pudimos obtener muy buenos resultados, tambien en gran medida gracias a los metodos de reduccion de varianza, en este caso, nuestro error se reducio de casi un 5% a un 0.07% al usar estos metodos.
#
# Con este error tan pequeño, podemos proceder a realizar los modelos de predicción y encontrar  una estimacion para los proximos dias

# %% [markdown]
# ## <center> <font color='navy'>5 . Modelos de Prediccion y Conclusiones <center> <font color='navy'>

# %% [markdown]
# **Modelado Nodo 1.** Positivos

# %%
escenarios, fecha_futura = 1000, 30 # definimos escenarios diarios a generar y dias futuros a simular
# mil escenarios por dia, a diez dias en el futuro
y_random = [acep_rechazo_positivos(func_positivos, max_fp, escenarios) for i in range(fecha_futura)] # encontrar escenarios futuros

y_random = np.array(np.transpose(y_random)) # transponer vector
dia = np.arange(0,fecha_futura-1,1) # arreglo con fechas futuras
pred_positivos = np.array([y_random.mean(axis=0).cumsum()[dia_i] for dia_i in dia]) # hacer suma acumulada por columna
print(pred_positivos)
y_random = pd.DataFrame(y_random) # hacer y random un data frame
# encontrar intervalos de confanza para cada prediccion
i2 = [st.norm.interval(0.90, loc=np.mean(y_random.iloc[:,i]), scale=st.sem(y_random.iloc[:,i])) for i in dia]

# generar df con resultados
simulacion_positivos = pd.DataFrame()
simulacion_positivos['Dia Futuro'] = dia+1
simulacion_positivos.set_index('Dia Futuro',inplace = True)
simulacion_positivos['Prediccion Puntual'] = pred_positivos
simulacion_positivos['Int Confianza'] = i2

simulacion_positivos
# Out:
# [ 2837421.89172131  5793922.87617133  8803599.27801302 11676982.04034851
#  14689599.77674543 17569735.03093117 20447521.95404362 23466775.3648932
#  26348490.23668901 29368627.39704609 32242884.07283199 35120249.67597386
#  38076706.19243465 41045865.93717245 44094450.54847952 47110214.50285396
#  50063181.29217514 52884626.76018493 55896964.29223436 58870036.53745937
#  61782656.42921863 64695502.64440392 67661299.10982975 70587286.77469426
#  73398344.75066806 76310483.99661073 79273130.1897748  82308792.02880673
#  85296077.91417415]
#             Prediccion Puntual                             Int Confianza
# Dia Futuro
# 1                 2.837422e+06   (2725457.032422781, 2949386.7510198317)
# 2                 5.793923e+06   (2842154.5023719366, 3070847.466528108)
# 3                 8.803599e+06  (2894952.7775362893, 3124400.0261471006)
# 4                 1.167698e+07   (2759373.930810011, 2987391.5938609494)
# 5                 1.468960e+07   (2897878.0826785197, 3127357.390115337)
# 6                 1.756974e+07   (2766795.171540896, 2993475.3368305964)
# 7                 2.044752e+07    (2765772.341161994, 2989801.505062885)
# 8                 2.346678e+07  (2902292.7804486733, 3136214.0412504934)
# 9                 2.634849e+07  (2767556.3550205156, 2995873.3885710966)
# 10                2.936863e+07   (2902916.208837512, 3137358.1118766526)
# 11                3.224288e+07   (2760204.584688436, 2988308.7668833607)
# 12                3.512025e+07   (2764305.3847107138, 2990425.821573037)
# 13                3.807671e+07  (2840275.7395980554, 3072637.2933235103)
# 14                4.104587e+07    (2854065.35013639, 3084254.1393392133)
# 15                4.409445e+07   (2933568.3739674515, 3163600.848646696)
# 16                4.711021e+07  (2901227.7263101093, 3130300.1824387875)
# 17                5.006318e+07  (2840480.7634205557, 3065452.8152218135)
# 18                5.288463e+07   (2707927.8965739086, 2934963.039445676)
# 19                5.589696e+07  (2896748.0019755387, 3127927.0621233336)
# 20                5.887004e+07    (2858921.245780321, 3087223.244669685)
# 21                6.178266e+07  (2797797.2737316964, 3027442.5097868303)
# 22                6.469550e+07    (2797569.847268775, 3028122.583101784)
# 23                6.766130e+07   (2852355.764005604, 3079237.1668460593)
# 24                7.058729e+07  (2812159.5430469057, 3039815.7866821084)
# 25                7.339834e+07   (2697631.194276714, 2924484.7576708957)
# 26                7.631048e+07  (2801253.4414454843, 3023025.0504398583)
# 27                7.927313e+07     (2848355.358439307, 3076937.02788881)
# 28                8.230879e+07    (2923746.756049512, 3147576.922014344)
# 29                8.529608e+07    (2871322.151051034, 3103249.619683829)

# %%
# Obtener cambio porcentual de los casos positivos
(pd.DataFrame(pred_positivos).pct_change().dropna()).values[15:]
# Out:
# array([[0.06268209],
#        [0.05635769],
#        [0.05696055],
#        [0.05318844],
#        [0.04947542],
#        [0.04714667],
#        [0.04584239],
#        [0.04324463],
#        [0.03982386],
#        [0.03967582],
#        [0.03882358],
#        [0.0382937 ],
#        [0.03629364]])

# %% [markdown]
# Se logro conseguir un modelo que predijera el comportamiento del covid, objetivo principal del proyecto, del cual se puede observar que el comportamiento del virus sera exponencial, pero poco a poco el cambio porcentual de los casos que aumentan de un dia a otro bajaran, esto debido a diferentes factores que afecta el corona virus, que tienen un crecimiento exponencial, de acuerdo a la carga viral del virus (que en este caso es muy grande debido al rango de propagacion).
#
# Se espera que los casos vayan disminuyendo poco de acuerdo al modelo generado y a los diferentes estudios que se hagan, obviamente este modelo es bueno, pero los virus tambien funcionan en ciertos momentos como cadenas de Markov, es decir, es posible que su comportamiento vaya cambiando conforme el tiempo, debido a los factores humanos como la interaccion humana que haya y las medidas de aislamiento que se apliquen.
#
# Es por eso que en los paises que iniciaron su pandemia cerrando fronteras y aplicando toques de queda, son los que tuvieron un aumento abrupto en los casos en un inicio, pero despues de un tiempo sus indices de contagio bajaron (tal es el caso de Japon).
#
# Mientras que en los paises que pusieron su economia primero y no aplicaron medidas de aislamientos el virs ha tardado mas en calmarse, tal es el caso de estados unidos, por eso podemos obsercar que el cambio porcentual se mantendra estable aproximadamente entre un 3% y 4%, que en este caso es mucho considerando la poblacion de 328.2 millones de estados unidos.

# %% [markdown]
# Referencias:
#
# - Ryding, S. (2020). 'Factores de Virulencia'. Recuperado de https://www.news-medical.net/health/What-are-Virulence-Factors-(Spanish).aspx

# %% [markdown]
# **Modelado Nodo 2.** Muertos

# %%
escenarios, fecha_futura = 10000, 30 # definimos escenarios diarios a generar y dias futuros a simular
# mil escenarios por dia, a diez dias en el futuro
y_random = [acep_rechazo_muertos(func_muertos, max_fm, escenarios) for i in range(fecha_futura)] # encontrar escenarios futuros

y_random = np.array(np.transpose(y_random)) # transponer vector
dia = np.arange(0,fecha_futura-1,1) # arreglo con fechas futuras
pred_muertos = np.array([y_random.mean(axis=0).cumsum()[dia_i] for dia_i in dia]) # hacer suma acumulada por columna

print(pred_muertos)
y_random = pd.DataFrame(y_random) # hacer y random un data frame
# encontrar intervalos de confanza para cada prediccion
i2 = [st.norm.interval(0.90, loc=np.mean(y_random.iloc[:,i]), scale=st.sem(y_random.iloc[:,i])) for i in dia]

# generar df con resultados
simulacion_muertos = pd.DataFrame()
simulacion_muertos['Dia Futuro'] = dia+1
simulacion_muertos.set_index('Dia Futuro',inplace = True)
simulacion_muertos['Prediccion Puntual'] = pred_muertos
simulacion_muertos['Int Confianza'] = i2

simulacion_muertos
# Out:
# [ 105784.60738313  211333.72248784  316970.89712897  423260.95474618
#   529912.81794244  635491.68360125  741428.08589721  847758.14095566
#   953191.13863607 1059341.1738509  1165676.3023947  1271780.6107584
#  1378330.2043833  1483590.76255871 1589106.04191716 1695429.47378217
#  1801801.27926985 1908380.47716283 2015030.2218995  2120667.34829194
#  2225746.64077349 2331541.30206102 2437003.89096771 2541475.56685301
#  2646353.8013544  2750672.80293516 2856192.15484244 2961991.35367863
#  3067922.42589875]
#             Prediccion Puntual                             Int Confianza
# Dia Futuro
# 1                 1.057846e+05  (104811.84396505133, 106757.37080120703)
# 2                 2.113337e+05  (104574.52015768297, 106523.71005173563)
# 3                 3.169709e+05  (104669.04058536213, 106605.30869689355)
# 4                 4.232610e+05     (105322.6533885522, 107257.461845879)
# 5                 5.299128e+05   (105684.50353484035, 107619.2228576709)
# 6                 6.354917e+05  (104611.38322195449, 106546.34809566397)
# 7                 7.414281e+05  (104970.78285439806, 106902.02173753573)
# 8                 8.477581e+05  (105363.75609771066, 107296.35401917202)
# 9                 9.531911e+05  (104460.18115003163, 106405.81421079065)
# 10                1.059341e+06  (105175.51666511183, 107124.55376455827)
# 11                1.165676e+06   (105373.05073294952, 107297.2063546498)
# 12                1.271781e+06   (105137.8683433965, 107070.74838400741)
# 13                1.378330e+06  (105579.18097943644, 107520.00627035653)
# 14                1.483591e+06  (104300.66451346762, 106220.45183735147)
# 15                1.589106e+06  (104544.82816775046, 106485.73054914152)
# 16                1.695429e+06    (105351.965682566, 107294.89804746832)
# 17                1.801801e+06  (105402.80254912864, 107340.80842621559)
# 18                1.908380e+06  (105616.32857788193, 107542.06720808752)
# 19                2.015030e+06   (105673.31179208258, 107626.1776812534)
# 20                2.120667e+06  (104671.96374524297, 106602.28903964051)
# 21                2.225747e+06  (104110.84562624444, 106047.73933685289)
# 22                2.331541e+06   (104828.33187078859, 106760.9907042633)
# 23                2.437004e+06  (104492.58206637061, 106432.59574701195)
# 24                2.541476e+06  (103505.34999525787, 105438.00177534799)
# 25                2.646354e+06  (103905.26978957749, 105851.19921319885)
# 26                2.750673e+06   (103345.57165544262, 105292.4315060736)
# 27                2.856192e+06  (104536.15625299465, 106502.54756158196)
# 28                2.961991e+06  (104828.74632209212, 106769.65135027577)
# 29                3.067922e+06  (104961.72230826368, 106900.42213197125)

# %%
print('En los proximos 30 dias se espera que el indice de mortalidad del covid sea de', pred_muertos.mean()/pred_positivos.mean()*100, '%')
print('El indice de mortalidad historico del covid fue de', media_muertos/media_positivos *100,'%' )
print('Por lo tanto el indice de mortalidad ha disminuido un poco con el tiempo')
# Out:
# En los proximos 30 dias se espera que el indice de mortalidad del covid sea de 3.6058850404164704 %
# El indice de mortalidad historico del covid fue de 3.63546616125801 %
# Por lo tanto el indice de mortalidad ha disminuido un poco con el tiempo

# %% [markdown]
# Se cumplio un objetivo secundario, que es el hecho de encontrar el indice de mortalidad del covid sobre el numero de positivos, podemos observar que el comportamiento historico del virus es de 3.63%, pero que en los proximos dias se espera un indice del 3.55%, esto es ad hoc a las noticias que vemos, ya que generalmente los indices de mortalidad de un virus van bajando conforme la curva de casos se aplana, debido a que mas gente se infecta y menos muere.
#
# Este indice ira bajando poco a poco conforme baja la curva de casos. De igual forma, si bien el presidente Trump ha mencionado que la tasa de estados unidos es la mas baja del mundo, esto no es verdad, ya que la tasa estaba rondando hace unos meses hasta en el 4.4% y actualmente esta aprox. 3.6%, secundado por los resultados de nuestro proyecto. Por lo cual, nuestros resultados estan muy cercanos a la realidad

# %% [markdown]
# Referencias:
#
# - Infobae. (2020). 'Tasa de Mortalidad USA'. Recuperado de https://www.infobae.com/america/eeuu/2020/07/08/donald-trump-afirmo-que-la-tasa-de-mortalidad-del-coronavirus-en-eeuu-es-la-mas-baja-del-mundo-es-la-septima-mas-alta/

# %% [markdown]
# **Modelado Nodo 3.** Hospitalizados

# %%
escenarios, fecha_futura = 10000, 30 # definimos escenarios diarios a generar y dias futuros a simular
# mil escenarios por dia, a diez dias en el futuro
y_random = [acep_rechazo_hospitalizados(func_hospitalizados, max_fh, escenarios) for i in range(fecha_futura)] # encontrar escenarios futuros

y_random = np.array(np.transpose(y_random)) # transponer vector
dia = np.arange(0,fecha_futura-1,1) # arreglo con fechas futuras
pred_hospitalizados = np.array([y_random.mean(axis=0).cumsum()[dia_i] for dia_i in dia]) # hacer suma acumulada por columna

print(pred_hospitalizados)

y_random = pd.DataFrame(y_random) # hacer y random un data frame
# encontrar intervalos de confanza para cada prediccion
i2 = [st.norm.interval(0.90, loc=np.mean(y_random.iloc[:,i]), scale=st.sem(y_random.iloc[:,i])) for i in dia]

# generar df con resultados
simulacion_hospitalizados = pd.DataFrame()
simulacion_hospitalizados['Dia Futuro'] = dia+1
simulacion_hospitalizados.set_index('Dia Futuro',inplace = True)
simulacion_hospitalizados['Prediccion Puntual'] = pred_hospitalizados
simulacion_hospitalizados['Int Confianza'] = i2

simulacion_hospitalizados
# Out:
# [  37966.65567968   75714.64390153  113650.1961145   151350.55448063
#   189047.47837518  226628.4867854   264286.78186631  301931.13115739
#   339577.76147948  377101.67111257  414938.86354726  452630.64190036
#   490319.95932054  527896.95153278  565564.6548229   603445.05301994
#   641157.79347485  678961.34282698  716895.28234009  754610.1356528
#   792183.32475641  829589.27652599  866999.60572281  904844.06258766
#   942462.0682535   980333.92526412 1018187.53114122 1055668.5353469
#  1093484.1077982 ]
#             Prediccion Puntual                             Int Confianza
# Dia Futuro
# 1                 3.796666e+04    (37713.63898532462, 38219.67237404139)
# 2                 7.571464e+04    (37491.49396633553, 38004.48247735412)
# 3                 1.136502e+05   (37682.70420547603, 38188.400220476215)
# 4                 1.513506e+05   (37439.220699379206, 37961.49603288305)
# 5                 1.890475e+05     (37436.5452946132, 37957.30249447335)
# 6                 2.266285e+05    (37322.35345321008, 37839.66336723946)
# 7                 2.642868e+05    (37400.53210106032, 37916.05806075361)
# 8                 3.019311e+05    (37388.94117326456, 37899.75740888644)
# 9                 3.395778e+05    (37390.52757495386, 37902.73306924251)
# 10                3.771017e+05   (37266.459067519565, 37781.36019865569)
# 11                4.149389e+05    (37580.02189466731, 38094.36297470088)
# 12                4.526306e+05    (37437.02374759976, 37946.53295860799)
# 13                4.903200e+05    (37436.93319142892, 37941.70164892622)
# 14                5.278970e+05   (37316.799196006046, 37837.18522848899)
# 15                5.655647e+05   (37411.50372550555, 37923.902854722415)
# 16                6.034451e+05    (37623.36243451348, 38137.43395955809)
# 17                6.411578e+05   (37453.794405702545, 37971.68650413124)
# 18                6.789613e+05    (37545.41778222694, 38061.68092203073)
# 19                7.168953e+05    (37678.95764828878, 38188.92137793025)
# 20                7.546101e+05   (37458.15420828276, 37971.552417129824)
# 21                7.921833e+05    (37314.19536448969, 37832.18284273215)
# 22                8.295893e+05    (37148.21243465822, 37663.69110451657)
# 23                8.669996e+05    (37151.89558854914, 37668.76280507491)
# 24                9.048441e+05  (37591.768892192624, 38097.144837509426)
# 25                9.424621e+05    (37361.54356200862, 37874.46776968494)
# 26                9.803339e+05   (37616.49429425376, 38127.219726968935)
# 27                1.018188e+06     (37598.5840637068, 38108.62769050716)
# 28                1.055669e+06    (37221.40551690694, 37740.60289445091)
# 29                1.093484e+06   (37559.545500312684, 38071.59940229285)

# %%
print('El ratio de personas con covid que seran hospitalizadas en los proximos 30 dias seran de las personas positivas sera de', pred_hospitalizados.mean()/pred_positivos.mean()*100,'%')
print('El ratio historico es de', hospitalizados.mean()/positivos.mean() * 100, '%')
print('Es decir en USA, solo un 1.30% de las personas con covid son hospitalizados, mientras que mueren 3.67% de las personas positivas')
# Out:
# El ratio de personas con covid que seran hospitalizadas en los proximos 30 dias seran de las personas positivas sera de 1.2841162477217303 %
# El ratio historico es de 1.3252027006713492 %
# Es decir en USA, solo un 1.30% de las personas con covid son hospitalizados, mientras que mueren 3.67% de las personas positivas

# %% [markdown]
# Se cumplio un tercer objetivo. Lo comentado anteriormente nos pone a pensar sobre el colapso de los hospitales y la falta de personal medico, como han mencionado distintos medios en estados unidos, y si bien, es una gran diferencia que 1.30% de las personas son hospitalizadas y mueran aun mas, esto es preocupante debido al hecho de que las personas hospitalizadas tienen buenas chances de recuperarse si ingresan al sector salud.
#
# La conclusion a la cual nos hace llegar a esto, es que como lo han mencionado distintos medios, en los hospitales se les ha negado la atencion medica a personas con covid si no tienen dinero, seguro e incluso ha habido casos donde por discriminacion por raza u orientacion sexual no se atiende a las personas. Lo cual es preocupante.

# %%
plt.plot(hospitalizados,label = 'datos reales hospitalizados')
plt.plot(muertos,label = 'datos reales muertos')
plt.legend()
plt.grid()
plt.show()
print('El indice de correlacion de Pearson para los datos historicos de los hospitalizados y los muertos es de', st.pearsonr(hospitalizados, muertos)[0])
# Out:
# El indice de correlacion de Pearson para los datos historicos de los hospitalizados y los muertos es de 0.40428335590200637

# %% [markdown]
# Lo anterior se hizo con la finalidad de mostrar el hecho de la deficiencia del sector salud, que claramente no esta cubriendo la demanda, y se entenderia si fuera un pais de escasos recursos, pero claramente estados unidos no le esta invirtiendo lo suficiente al sector salud, mientras el numero de muertos aumenta, el numero de hospitalizados ta,bien deberia de hacerlo en la misma proporcion o muy cercano.
#
# Mientras tanto, el indice de correlacion de pearson muestra que aunque los datos estan correlacionados positivamente (si uno crece el otro tambien), la relacion es de 0.40, y lo ideal en un pais con pandemia es que se le de abasto a las personas que estan enfermas, sin importar su condicion, debido a lo caro que es la atencion, la mayoria no lo puede pagar, un estudio a mostrado que para aliviarse de COVID en un hospital minimo se necesitan 20,000 dolares que son aproximadamente 400,000 pesos mexicanos, minimo.
#
# El presidente no ha mostrado interes por financiar a las personas de bajos recursos en este sentido y por eso que hay tanta disparidad entre los muertos y los hospitalizados por covid

# %% [markdown]
# Referencias:
#
# - Syracuse University. (2020). 'El colapso del sistema de salud estadounidense'. Recuperado de https://lernercenter.syr.edu/2020/08/10/ib-38/
# - The Atlantic. (2020). 'How much does it cost to get covid-19'. Recuperado de https://www.theatlantic.com/health/archive/2020/04/how-much-does-it-cost-to-get-covid-19/610813/

# %% [markdown]
# Modelado Nodo 4.

# %%
escenarios, fecha_futura = 10000, 30 # definimos escenarios diarios a generar y dias futuros a simular
# mil escenarios por dia, a diez dias en el futuro
y_random = [acep_rechazo_recuperados(func_recuperados, max_fr, escenarios) for i in range(fecha_futura)] # encontrar escenarios futuros

y_random = np.array(np.transpose(y_random)) # transponer vector
dia = np.arange(0,fecha_futura-1,1) # arreglo con fechas futuras
pred_recuperados = np.array([y_random.mean(axis=0).cumsum()[dia_i] for dia_i in dia]) # hacer suma acumulada por columna

print(pred_recuperados)

y_random = pd.DataFrame(y_random) # hacer y random un data frame
# encontrar intervalos de confanza para cada prediccion
i2 = [st.norm.interval(0.90, loc=np.mean(y_random.iloc[:,i]), scale=st.sem(y_random.iloc[:,i])) for i in dia]

# generar df con resultados
simulacion_recuperados = pd.DataFrame()
simulacion_recuperados['Dia Futuro'] = dia+1
simulacion_recuperados.set_index('Dia Futuro',inplace = True)
simulacion_recuperados['Prediccion Puntual'] = pred_recuperados
simulacion_recuperados['Int Confianza'] = i2

simulacion_recuperados
# Out:
# [ 1069143.35591456  2124977.02029004  3208805.31740162  4286336.99132226
#   5360365.21534283  6427513.77452246  7490336.71563674  8559497.45055745
#   9634920.16998187 10708722.98931824 11782508.15592393 12855110.90409359
#  13922385.57729886 14999163.16174555 16073830.72954992 17155796.1898713
#  18221826.39066408 19283149.66646121 20347495.11865978 21414567.84942982
#  22493752.00606404 23559711.18052756 24628708.72380138 25716671.70886857
#  26791362.84387453 27868138.60169796 28946777.7246408  30010117.88619071
#  31077381.00707908]
#             Prediccion Puntual                             Int Confianza
# Dia Futuro
# 1                 1.069143e+06  (1055314.1783340327, 1082972.5334950862)
# 2                 2.124977e+06   (1041948.635564707, 1069718.6931862629)
# 3                 3.208805e+06  (1069934.0020698344, 1097722.5921533152)
# 4                 4.286337e+06   (1063584.545166584, 1091478.8026746993)
# 5                 5.360365e+06  (1060053.2606612558, 1088003.1873798973)
# 6                 6.427514e+06  (1053264.7858751356, 1081032.3324841266)
# 7                 7.490337e+06   (1048959.169775953, 1076686.7124525998)
# 8                 8.559497e+06   (1055205.975746881, 1083115.4940945215)
# 9                 9.634920e+06   (1061542.111422357, 1089303.3274264818)
# 10                1.070872e+07  (1059859.0937700358, 1087746.5449026881)
# 11                1.178251e+07   (1059863.858601503, 1087706.4746098658)
# 12                1.285511e+07  (1058715.3244795704, 1086490.1718597675)
# 13                1.392239e+07  (1053339.7906169419, 1081209.5557935953)
# 14                1.499916e+07  (1062838.8060734628, 1090716.3628199266)
# 15                1.607383e+07  (1060683.8030501592, 1088651.3325585795)
# 16                1.715580e+07  (1067976.7702248315, 1095954.1504179044)
# 17                1.822183e+07   (1052226.7715191748, 1079833.630066398)
# 18                1.928315e+07  (1047427.0114063352, 1075219.5401879312)
# 19                2.034750e+07   (1050493.9844511296, 1078196.919946006)
# 20                2.141457e+07  (1053210.5998264754, 1080934.8617136169)
# 21                2.249375e+07   (1065344.586366468, 1093023.7269019745)
# 22                2.355971e+07    (1052122.4990798668, 1079795.84984719)
# 23                2.462871e+07  (1055088.1762616697, 1082906.9102859634)
# 24                2.571667e+07   (1073987.6394679577, 1101938.330666417)
# 25                2.679136e+07  (1060817.1682777638, 1088565.1017341558)
# 26                2.786814e+07   (1062847.822807965, 1090703.6928389005)
# 27                2.894678e+07  (1064718.6759627084, 1092559.5699229566)
# 28                3.001012e+07  (1049544.7183251372, 1077135.6047746777)
# 29                3.107738e+07    (1053366.3249560636, 1081159.91682069)

# %%
print('La probabilidad en los proximos 30 dias de recuperarse en caso de ser positivo en USA es de', 100 * (pred_recuperados/pred_positivos).mean(), '%' )
# Out:
# La probabilidad en los proximos 30 dias de recuperarse en caso de ser positivo en USA es de 36.53694674876943 %

# %% [markdown]
# La respuesta/conclusion al ultimo objetivo secundario es una de las revelaciones mas impresionantes de este proyecto, como se menciona en la siguiente referencia, estados unidos al dia de hoy tiene la tasa de recuperacion mas chica del mundo, que se encuentra en aproximadamente 39% al mes de septiembre, a comparacion de la global que es de aproximadamente 70%.
#
# Aqui esta un claro ejemplo de que no se le invirtio lo suficiente al area medica, en estados unidos se puso primero la economia, y djo de lado los demas, el presidente Trump menciono en reiteradas ocasiones que la tasa de recuperacion de covid es del 99%, hoy, las estadisticas que acabamos de comprobar, nos dicen que estan en aproximadamente 37%, lo cual indica que el gobierno estadounidense no ha tenido un buen manejo en materia de salubridad de la pandemia.

# %% [markdown]
# Referencia:
#
# - rappler (2020), 'FALSO 99% DE LAS PERSONAS NO SE RECUPERA DE CORONA VIRUS'. Recuperado de https://www.rappler.com/newsbreak/fact-check/trump-says-people-recover-from-covid-19

# %% [markdown]
# #### **Conclusion General en materia del proyecto**
#
# A manera de conclusion del proyecto y de los aprendizajes en este Tema 2 de la materia, podemos decir que los resultados, conclusiones generales y las predicciones, se acercan mucho a los comentados por los medios a lo largo del tiempo. Por lo cual pudimos confirmar la importancia de los metodos vistos en clase, ademas de su aplicacion en la vida real.
#
# Esta es muy importante para predecir no solo modelos como el covid, si no que las funciones de distribuciones y las herramientas de generacion de numeros aleatorias, junto con el KDE y los demas elementos, podrian predecir cualquier hecho o suceso que nos guste modelar.
#
# Como conclusion del proyecto, podemos ver que en las diferentes conclusiones especificas notamos que el manejo de la pandemia de estados unidos no es la mejor, tiene uno de los mayores indices de mortalidad mundiales, su numero de positivos sigue en crecimiento exponencial y no han hecho mucho en el sector salud para tener mas infraestructura y disminuir el numero de muertos, ademas de aumentar el numero de hospitalizados y analogamente, el numero de recuperados.
#
# Por lo que, la recomendacion directa es que si se quiere cambiar las predicciones malas que tiene enfrente el gobierno de Estados Unidos, se recomienda invertir mas en salud, para lograr cambiar los rubros comentados anteriormente.

# %% [markdown]
# **Referencias.**
#
# - SRK. (2020). 'Base de Datos COVID - Introduccion' Recuperado el 1 de octubre del 2020 del sitio web: https://www.kaggle.com/sudalairajkumar
# - NYTIMES. (2020) 'Mapa CoronaVirus USA'. Recuperado el 1 de octubre del 2020 del sitio web: https://www.nytimes.com/es/interactive/2020/espanol/mundo/coronavirus-en-estados-unidos.html
# - Wikipedia. (2020). 'COVID-19'. Recuperado el 15 de octubre del 2020 del sitio web: https://es.wikipedia.org/wiki/COVID-19
# - Infobae. (2020). 'Tasa de mortalidad USA' Recuperado el 10 de noviembre del 2020 del sitio web:https://www.infobae.com/america/eeuu/2020/07/08/donald-trump-afirmo-que-la-tasa-de-mortalidad-del-coronavirus-en-eeuu-es-la-mas-baja-del-mundo-es-la-septima-mas-alta/
# - Ryding, S. (2020). 'Factores de Virulencia'. Recuperado de https://www.news-medical.net/health/What-are-Virulence-Factors-(Spanish).aspx
# - Syracuse University. (2020). 'El colapso del sistema de salud estadounidense'. Recuperado de https://lernercenter.syr.edu/2020/08/10/ib-38/
# - The Atlantic. (2020). 'How much does it cost to get covid-19'. Recuperado de https://www.theatlantic.com/health/archive/2020/04/how-much-does-it-cost-to-get-covid-19/610813/
